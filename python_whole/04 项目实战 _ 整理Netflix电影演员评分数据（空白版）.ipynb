# %% [markdown]
# # 项目：整理Netflix电影演员评分数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析的目的是，整理不同流派影视作品，比如喜剧片、动作片、科幻片中，各演员出演作品的平均IMDB评分，从而挖掘出各个流派中的高评分作品演员。
#
# 本实战项目的目的在于练习整理数据，从而得到可供下一步分析的数据。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据集记录了截止至2022年7月美国地区可观看的所有Netflix电视剧及电影数据。数据集包含两个数据表：`titles.csv`和`credits.csv`。
#
# `titles.csv`包含电影及电视剧相关信息，包括影视作品ID、标题、类型、描述、流派、IMDB（一个国外的在线评分网站）评分，等等。`credits.csv`包含超过7万名出现在Netflix影视作品的导演及演员信息，包括名字、影视作品ID、人物名、演职员类型（导演/演员）等。

# %% [markdown]
# `titles.csv`每列的含义如下：
# - id：影视作品ID。
# - title：影视作品标题。
# - show_type：作品类型，电视节目或电影。
# - description：简短描述。
# - release_year：发布年份。
# - age_certification：适龄认证。
# - runtime：每集电视剧或电影的长度。
# - genres：流派类型列表。
# - production_countries：出品国家列表。
# - seasons：如果是电视剧，则是季数。
# - imdb_id：IMDB的ID。
# - imdb_score：IMDB的评分。
# - imdb_votes：IMDB的投票数。
# - tmdb_popularity：TMDB的流行度。
# - tmdb_score：TMDB的评分。
#
# `credits.csv`每列的含义如下：
# - person_ID：演职员ID。
# - id：参与的影视作品ID。
# - name：姓名。
# - character_name：角色姓名。
# - role：演职员类型，演员或导演。

# %%
import pandas as pd
import numpy as np

# %%
titles = pd.read_csv('./files/titles.csv')
credits = pd.read_csv('./files/credits.csv')

# %%
titles.head(10)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
# 5   ts22164         Monty Python's Flying Circus   SHOW
# 6   tm70993                        Life of Brian  MOVIE
# 7   tm14873                          Dirty Harry  MOVIE
# 8  tm119281                     Bonnie and Clyde  MOVIE
# 9   tm98978                      The Blue Lagoon  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# ...

# %%
credits.head(10)
# Out:
#    person_id       id             name                      character   role
# 0       3748  tm84618   Robert De Niro                  Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster                  Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                            Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel        Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                          Betsy  ACTOR
# 5      32267  tm84618      Peter Boyle                         Wizard  ACTOR
# 6     519612  tm84618   Leonard Harris      Senator Charles Palantine  ACTOR
# 7      29068  tm84618   Diahnne Abbott                Concession Girl  ACTOR
# 8     519613  tm84618      Gino Ardito             Policeman at Rally  ACTOR
# 9       3308  tm84618  Martin Scorsese  Passenger Watching Silhouette  ACTOR

# %%
titles_copy = titles.copy()
credits_copy = credits.copy()

# %%
titles_copy["genres"][0]
# Out:
# "['documentation']"

# %%
titles_copy["genres"] = titles_copy["genres"].apply(lambda genres: eval(genres))
titles_copy["genres"][0]
# Out:
# ['documentation']

# %%
titles_copy = titles_copy.explode("genres")

# %%
titles_copy.head(10)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# ...

# %%
titles_copy["production_countries"][0]
# Out:
# "['US']"

# %%
titles_copy["production_countries"] = titles_copy["production_countries"].apply(lambda production_countries: eval(production_countries))

# %%
titles_copy["production_countries"][0]
# Out:
# ['US']

# %%
titles_copy["production_countries"] = titles_copy["production_countries"].explode("production_countries")

# %%
titles_copy["production_countries"][0]
# Out:
# 'US'

# %%
titles_copy.head(10)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# ...

# %%
titles_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15147 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    15147 non-null  object
#  1   title                 15146 non-null  object
#  2   type                  15147 non-null  object
#  3   description           15125 non-null  object
#  4   release_year          15147 non-null  int64
#  5   age_certification     9298 non-null   object
#  6   runtime               15147 non-null  int64
#  7   genres                15088 non-null  object
#  8   production_countries  15061 non-null  object
#  9   seasons               5923 non-null   float64
#  10  imdb_id               14525 non-null  object
#  11  imdb_score            14399 non-null  float64
#  12  imdb_votes            14375 non-null  float64
#  13  tmdb_popularity       14995 non-null  float64
#  14  tmdb_score            14614 non-null  float64
# ...

# %%
titles_copy["release_year"] = pd.to_datetime(titles_copy["release_year"],format="%Y")

# %%
titles_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15147 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    15147 non-null  object
#  1   title                 15146 non-null  object
#  2   type                  15147 non-null  object
#  3   description           15125 non-null  object
#  4   release_year          15147 non-null  datetime64[ns]
#  5   age_certification     9298 non-null   object
#  6   runtime               15147 non-null  int64
#  7   genres                15088 non-null  object
#  8   production_countries  15061 non-null  object
#  9   seasons               5923 non-null   float64
#  10  imdb_id               14525 non-null  object
#  11  imdb_score            14399 non-null  float64
#  12  imdb_votes            14375 non-null  float64
#  13  tmdb_popularity       14995 non-null  float64
# ...

# %%
credits_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77801 entries, 0 to 77800
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77801 non-null  int64
#  1   id         77801 non-null  object
#  2   name       77801 non-null  object
#  3   character  68029 non-null  object
#  4   role       77801 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.0+ MB

# %%
credits_copy["person_id"] = credits_copy["person_id"].astype("str")

# %%
credits_copy.head(10)
# Out:
#   person_id       id             name                      character   role
# 0      3748  tm84618   Robert De Niro                  Travis Bickle  ACTOR
# 1     14658  tm84618     Jodie Foster                  Iris Steensma  ACTOR
# 2      7064  tm84618    Albert Brooks                            Tom  ACTOR
# 3      3739  tm84618    Harvey Keitel        Matthew 'Sport' Higgins  ACTOR
# 4     48933  tm84618  Cybill Shepherd                          Betsy  ACTOR
# 5     32267  tm84618      Peter Boyle                         Wizard  ACTOR
# 6    519612  tm84618   Leonard Harris      Senator Charles Palantine  ACTOR
# 7     29068  tm84618   Diahnne Abbott                Concession Girl  ACTOR
# 8    519613  tm84618      Gino Ardito             Policeman at Rally  ACTOR
# 9      3308  tm84618  Martin Scorsese  Passenger Watching Silhouette  ACTOR

# %%
titles_copy.query("imdb_score.isnull()")
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 75     tm132164                       Bill Hicks: Sane Man  MOVIE
# 145    ts251477                            My First Errand   SHOW
# 145    ts251477                            My First Errand   SHOW
# 145    ts251477                            My First Errand   SHOW
# ...         ...                                        ...    ...
# 5810  tm1225897                                 Social Man  MOVIE
# 5833   ts307884                                 HQ Barbers   SHOW
# 5840  tm1216735                            Sun of the Soil  MOVIE
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#                                             description release_year  \
# 0     This collection includes 12 World War II-era p...   1945-01-01
# ...

# %%
titles_copy = titles_copy.dropna(subset=["imdb_score"])

# %%
titles_copy["imdb_score"].isnull().sum()
# Out:
# np.int64(0)

# %%
titles_copy.query("genres.isnull()")
# Out:
#              id                                              title   type  \
# 1813    ts77824  My Next Guest Needs No Introduction With David...   SHOW
# 1939   ts215037                              Minecraft: Story Mode   SHOW
# 2386    ts74805                   A Little Help with Carol Burnett   SHOW
# 2658   ts265844                                           #ABtalks   SHOW
# 4274  tm1172010                                  The Lockdown Plan  MOVIE
# 4648  tm1113921                                           In Vitro  MOVIE
#
#                                             description release_year  \
# 1813  TV legend David Letterman teams up with fascin...   2018-01-01
# 1939  MInecraft: Story Mode is an interactive, anima...   2018-01-01
# 2386  In this unscripted series starring comedy lege...   2018-01-01
# 2658  #ABtalks is a YouTube interview show hosted by...   2018-01-01
# 4274                                                NaN   2020-01-01
# ...

# %%
titles_copy = titles_copy.dropna(subset=["genres"])

# %%
titles_copy["genres"].isnull().sum()
# Out:
# np.int64(0)

# %%
titles_copy.duplicated().sum()
# Out:
# np.int64(0)

# %%
credits_copy.duplicated().sum()
# Out:
# np.int64(0)

# %%
titles_copy["genres"].value_counts()
# Out:
# genres
# drama            2827
# comedy           2218
# thriller         1180
# action           1109
# romance           955
# crime             909
# documentation     859
# family            652
# animation         630
# fantasy           619
# scifi             560
# european          428
# horror            366
# history           254
# music             244
# reality           219
# sport             170
# war               155
# western            39
# Name: count, dtype: int64

# %%
titles_copy = titles_copy.query("genres != ''")

# %%
titles_copy.query("genres == ''")
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %%
titles_copy["production_countries"].value_counts()
# Out:
# production_countries
# US         5200
# IN         2059
# JP         1148
# GB         1021
# CA          662
#            ...
# KW            4
# PL            4
# VN            3
# Lebanon       2
# PK            2
# Name: count, Length: 76, dtype: int64

# %%
with pd.option_context('display.max_rows', None):
    print(titles_copy["production_countries"].value_counts())
# Out:
# production_countries
# US         5200
# IN         2059
# JP         1148
# GB         1021
# CA          662
# FR          620
# DE          287
# KR          263
# PH          212
# AU          193
# HK          152
# TR          147
# ES          143
# CN          140
# IT          126
# LB          121
# EG          117
# TW          109
# MX           93
# NG           91
# CO           79
# DK           78
# AR           70
# BR           66
# PS           63
# ZA           62
# AE           62
# NO           62
# NL           61
# BE           53
# SG           52
# RU           48
# SE           46
# IE           37
# CH           35
# AT           34
# QA           32
# MY           32
# CL           26
# IL           26
# XX           24
# CZ           23
# CD           22
# FI           20
# MT           20
# MA           20
# RO           19
# BG           18
# SU           17
# UA           15
# ID           14
# JO           14
# IR           13
# BS           13
# ...

# %%
titles_copy["production_countries"] = titles_copy["production_countries"].replace({"Lebanon":"LB"})

# %%
with pd.option_context('display.max_rows', None):
    print(titles_copy["production_countries"].value_counts())
# Out:
# production_countries
# US    5200
# IN    2059
# JP    1148
# GB    1021
# CA     662
# FR     620
# DE     287
# KR     263
# PH     212
# AU     193
# HK     152
# TR     147
# ES     143
# CN     140
# IT     126
# LB     123
# EG     117
# TW     109
# MX      93
# NG      91
# CO      79
# DK      78
# AR      70
# BR      66
# PS      63
# NO      62
# AE      62
# ZA      62
# NL      61
# BE      53
# SG      52
# RU      48
# SE      46
# IE      37
# CH      35
# AT      34
# MY      32
# QA      32
# IL      26
# CL      26
# XX      24
# CZ      23
# CD      22
# MT      20
# MA      20
# FI      20
# RO      19
# BG      18
# SU      17
# UA      15
# ID      14
# JO      14
# BS      13
# IR      13
# HU      12
# LU      11
# IS      10
# GH       9
# PT       8
# HR       7
# TN       7
# PE       7
# BY       7
# DZ       6
# BF       6
# NZ       6
# SA       6
# VE       5
# SY       5
# GL       5
# UY       4
# PL       4
# KW       4
# VN       3
# PK       2
# ...

# %%
credits_copy["role"].value_counts()
# Out:
# role
# ACTOR       73251
# DIRECTOR     4550
# Name: count, dtype: int64

# %%
credits_copy["role"] = credits_copy["role"].astype("category")

# %%
credits_copy["role"].value_counts()
# Out:
# role
# ACTOR       73251
# DIRECTOR     4550
# Name: count, dtype: int64

# %%
titles_copy.describe()
# Out:
#                         release_year       runtime      seasons    imdb_score  \
# count                          14393  14393.000000  5655.000000  14393.000000
# mean   2015-12-30 06:28:41.336760832     78.326270     2.424934      6.534802
# min              1954-01-01 00:00:00      0.000000     1.000000      1.500000
# 25%              2015-01-01 00:00:00     44.000000     1.000000      5.800000
# 50%              2018-01-01 00:00:00     87.000000     1.000000      6.600000
# 75%              2020-01-01 00:00:00    106.000000     3.000000      7.400000
# max              2022-01-01 00:00:00    225.000000    42.000000      9.500000
# std                              NaN     40.555015     2.867856      1.157513
#
#          imdb_votes  tmdb_popularity    tmdb_score
# count  1.437100e+04     14268.000000  13975.000000
# mean   2.836162e+04        30.008057      6.885143
# min    5.000000e+00         0.600000      1.000000
# 25%    7.080000e+02         3.911750      6.200000
# ...

# %%
titles_copy
# Out:
#              id                               title   type  \
# 1       tm84618                         Taxi Driver  MOVIE
# 1       tm84618                         Taxi Driver  MOVIE
# 2      tm154986                         Deliverance  MOVIE
# 2      tm154986                         Deliverance  MOVIE
# 2      tm154986                         Deliverance  MOVIE
# ...         ...                                 ...    ...
# 5846   tm898842                         C/O Kaadhal  MOVIE
# 5847  tm1059008                             Lokillo  MOVIE
# 5849   ts271048  Mighty Little Bheem: Kite Festival   SHOW
# 5849   ts271048  Mighty Little Bheem: Kite Festival   SHOW
# 5849   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description release_year  \
# 1     A mentally unstable Vietnam War veteran works ...   1976-01-01
# 1     A mentally unstable Vietnam War veteran works ...   1976-01-01
# ...

# %%
credits_copy
# Out:
#       person_id         id                name                character  \
# 0          3748    tm84618      Robert De Niro            Travis Bickle
# 1         14658    tm84618        Jodie Foster            Iris Steensma
# 2          7064    tm84618       Albert Brooks                      Tom
# 3          3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4         48933    tm84618     Cybill Shepherd                    Betsy
# ...         ...        ...                 ...                      ...
# 77796    736339  tm1059008    Adelaida Buscato                María Paz
# 77797    399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798    373198  tm1059008         Inés Prieto                    Fanny
# 77799    378132  tm1059008        Isabel Gaona                   Cacica
# 77800   1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# ...

# %%
credits_with_titles = pd.merge(credits_copy,titles_copy,on="id",how="inner")

# %%
credits_with_titles.head(10)
# Out:
#   person_id       id             name                character   role  \
# 0      3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 2     14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 3     14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 4      7064  tm84618    Albert Brooks                      Tom  ACTOR
# 5      7064  tm84618    Albert Brooks                      Tom  ACTOR
# 6      3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 7      3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 8     48933  tm84618  Cybill Shepherd                    Betsy  ACTOR
# 9     48933  tm84618  Cybill Shepherd                    Betsy  ACTOR
#
#          title   type                                        description  \
# 0  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# ...

# %%
actor_with_titles = credits_with_titles.query("role == 'ACTOR'")

# %%
actor_with_titles.head(10)
# Out:
#   person_id       id             name                character   role  \
# 0      3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 2     14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 3     14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 4      7064  tm84618    Albert Brooks                      Tom  ACTOR
# 5      7064  tm84618    Albert Brooks                      Tom  ACTOR
# 6      3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 7      3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 8     48933  tm84618  Cybill Shepherd                    Betsy  ACTOR
# 9     48933  tm84618  Cybill Shepherd                    Betsy  ACTOR
#
#          title   type                                        description  \
# 0  Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# ...

# %%
groupby_actor_with_titles = actor_with_titles.groupby(["genres","person_id"])

# %%
imdb_groupby_actor_with_titles = groupby_actor_with_titles["imdb_score"].mean()

# %%
imdb_groupby_actor_with_titles.head(10)
# Out:
# genres  person_id
# action  1000         6.866667
#         100007       7.000000
#         100013       6.400000
#         100019       6.500000
#         100020       6.500000
#         100021       6.500000
#         100022       6.500000
#         100023       6.500000
#         100033       5.600000
#         100051       5.900000
# Name: imdb_score, dtype: float64

# %%
imdb_groupby_actor_with_titles_df = imdb_groupby_actor_with_titles.reset_index()

# %%
imdb_groupby_actor_with_titles_df.head(10)
# Out:
#    genres person_id  imdb_score
# 0  action      1000    6.866667
# 1  action    100007    7.000000
# 2  action    100013    6.400000
# 3  action    100019    6.500000
# 4  action    100020    6.500000
# 5  action    100021    6.500000
# 6  action    100022    6.500000
# 7  action    100023    6.500000
# 8  action    100033    5.600000
# 9  action    100051    5.900000

# %%
genres_max_score = imdb_groupby_actor_with_titles_df.groupby("genres")["imdb_score"].max()

# %%
genres_max_score
# Out:
# genres
# action           9.3
# animation        9.3
# comedy           9.2
# crime            9.5
# documentation    9.1
# drama            9.5
# european         8.9
# family           9.3
# fantasy          9.3
# history          9.1
# horror           9.0
# music            8.8
# reality          8.9
# romance          9.2
# scifi            9.3
# sport            9.1
# thriller         9.5
# war              8.8
# western          8.9
# Name: imdb_score, dtype: float64

# %%
genres_max_score_id = pd.merge(imdb_groupby_actor_with_titles_df,genres_max_score,on=["genres","imdb_score"])

# %%
genres_max_score_id.head(10)
# Out:
#       genres person_id  imdb_score
# 0     action     12790         9.3
# 1     action      1303         9.3
# 2     action     21033         9.3
# 3     action    336830         9.3
# 4     action     86591         9.3
# 5  animation      1303         9.3
# 6  animation     21033         9.3
# 7  animation     28024         9.3
# 8  animation    336830         9.3
# 9  animation     86591         9.3

# %%
genres_max_score_name = credits_copy[["person_id","name"]].drop_duplicates()

# %%
genres_max_score_name.head(10)
# Out:
#   person_id             name
# 0      3748   Robert De Niro
# 1     14658     Jodie Foster
# 2      7064    Albert Brooks
# 3      3739    Harvey Keitel
# 4     48933  Cybill Shepherd
# 5     32267      Peter Boyle
# 6    519612   Leonard Harris
# 7     29068   Diahnne Abbott
# 8    519613      Gino Ardito
# 9      3308  Martin Scorsese

# %%
genres_max_score_name_result = pd.merge(genres_max_score_id,genres_max_score_name,on=["person_id"])

# %%
genres_max_score_name_result
# Out:
#       genres person_id  imdb_score                name
# 0     action     12790         9.3         Olivia Hack
# 1     action      1303         9.3       Jessie Flower
# 2     action     21033         9.3          Zach Tyler
# 3     action    336830         9.3     André Sogliuzzo
# 4     action     86591         9.3       Cricket Leigh
# ..       ...       ...         ...                 ...
# 131      war    826547         8.8         Yuto Uemura
# 132  western     22311         8.9     Koichi Yamadera
# 133  western     28166         8.9  Megumi Hayashibara
# 134  western     28180         8.9      Unsho Ishizuka
# 135  western     93017         8.9            Aoi Tada
#
# [136 rows x 4 columns]

# %%
genres_max_score_name_result = genres_max_score_name_result.sort_values("genres").reset_index().drop("index",axis=1)

# %%
genres_max_score_name_result
# Out:
#       genres person_id  imdb_score                name
# 0     action     12790         9.3         Olivia Hack
# 1     action      1303         9.3       Jessie Flower
# 2     action     21033         9.3          Zach Tyler
# 3     action    336830         9.3     André Sogliuzzo
# 4     action     86591         9.3       Cricket Leigh
# ..       ...       ...         ...                 ...
# 131      war    826547         8.8         Yuto Uemura
# 132  western     28180         8.9      Unsho Ishizuka
# 133  western     22311         8.9     Koichi Yamadera
# 134  western     28166         8.9  Megumi Hayashibara
# 135  western     93017         8.9            Aoi Tada
#
# [136 rows x 4 columns]
