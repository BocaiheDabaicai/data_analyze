# %% [markdown]
# # 项目：用线性回归预测房价数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析报告的目的是，基于已有的房屋销售价格，以及有关该房屋的属性，进行线性回归分析，从而利用得到的线性回归模型，能对以下未知售价的房屋根据属性进行价格预测：
#
# 面积为6500平方英尺，有4个卧室、2个厕所，总共2层，不位于主路，无客人房，带地下室，有热水器，没有空调，车位数为2，位于城市首选社区，简装修。

# %% [markdown]
# ## 简介

# %% [markdown]
# 数据集`house_price.csv`记录了超过五百栋房屋的交易价格，以及房屋的相关属性信息，包括房屋面积、卧室数、厕所数、楼层数、是否位于主路、是否有客房，等等。

# %% [markdown]
# `house_price.csv`每列的含义如下：
# - price：房屋出售价格
# - area：房屋面积，以平方英尺为单位
# - bedrooms：卧室数
# - bathrooms：厕所数
# - stories：楼层数
# - mainroad：是否位于主路
#    - yes  是
#    - no	  否
# - guestroom：是否有客房
#    - yes  是
#    - no	  否
# - basement：是否有地下室
#    - yes  是
#    - no	  否
# - hotwaterheating：是否有热水器
#    - yes  是
#    - no	  否
# - airconditioning：是否有空调
#    - yes  是
#    - no	  否
# - parking：车库容量，以车辆数量为单位
# - prefarea：是否位于城市首选社区
#    - yes  是
#    - no	  否
# - furnishingstatus：装修状态
#    - furnished       精装
#    - semi-furnished	 简装
#    - unfurnished     毛坯

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../datas_mechine/house_price.csv")
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
data["mainroad"] = data["mainroad"].astype("category")
data["guestroom"] = data["guestroom"].astype("category")
data["basement"] = data["basement"].astype("category")
data["hotwaterheating"] = data["hotwaterheating"].astype("category")
data["airconditioning"] = data["airconditioning"].astype("category")
data["prefarea"] = data["prefarea"].astype("category")
data["furnishingstatus"] = data["furnishingstatus"].astype("category")

# %%
sns.pairplot(data,hue="mainroad")

# %%
import statsmodels.api as sm

# %%
data_copy = data.copy()
data_copy
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data_copy = pd.get_dummies(data_copy,columns=["mainroad","guestroom","basement","hotwaterheating","airconditioning","prefarea","furnishingstatus"],dtype=int,drop_first=True)
data_copy
# Out:
#         price  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0    13300000  7420         4          2        3        2             1
# 1    12250000  8960         4          4        4        3             1
# 2    12250000  9960         3          2        2        2             1
# 3    12215000  7500         4          2        2        3             1
# 4    11410000  7420         4          1        2        2             1
# ..        ...   ...       ...        ...      ...      ...           ...
# 540   1820000  3000         2          1        1        2             1
# 541   1767150  2400         3          1        1        0             0
# 542   1750000  3620         2          1        1        0             1
# 543   1750000  2910         3          1        1        0             0
# 544   1750000  3850         3          1        2        0             1
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# ...

# %%
y = data_copy["price"]
x = data_copy.drop(columns=["price"],axis=1)
print(y)
print(x)
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64
#      area  bedrooms  bathrooms  stories  parking  mainroad_yes  guestroom_yes  \
# 0    7420         4          2        3        2             1              0
# 1    8960         4          4        4        3             1              0
# 2    9960         3          2        2        2             1              0
# 3    7500         4          2        2        3             1              0
# 4    7420         4          1        2        2             1              1
# ..    ...       ...        ...      ...      ...           ...            ...
# 540  3000         2          1        1        2             1              0
# 541  2400         3          1        1        0             0              0
# ...

# %%
model = sm.OLS(y,x)
result  = model.fit()

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.958
# Model:                            OLS   Adj. R-squared (uncentered):              0.957
# Method:                 Least Squares   F-statistic:                              924.4
# Date:                Fri, 18 Apr 2025   Prob (F-statistic):                        0.00
# Time:                        10:29:21   Log-Likelihood:                         -8331.5
# No. Observations:                 545   AIC:                                  1.669e+04
# Df Residuals:                     532   BIC:                                  1.674e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
x = data_copy.drop(columns=["price","furnishingstatus_semi-furnished","bedrooms"],axis=1)
x
# Out:
#      area  bathrooms  stories  parking  mainroad_yes  guestroom_yes  \
# 0    7420          2        3        2             1              0
# 1    8960          4        4        3             1              0
# 2    9960          2        2        2             1              0
# 3    7500          2        2        3             1              0
# 4    7420          1        2        2             1              1
# ..    ...        ...      ...      ...           ...            ...
# 540  3000          1        1        2             1              0
# 541  2400          1        1        0             0              0
# 542  3620          1        1        0             1              0
# 543  2910          1        1        0             0              0
# 544  3850          1        2        0             1              0
#
#      basement_yes  hotwaterheating_yes  airconditioning_yes  prefarea_yes  \
# 0               0                    0                    1             1
# ...

# %%
model = sm.OLS(y,x)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              1088.
# Date:                Fri, 18 Apr 2025   Prob (F-statistic):                        0.00
# Time:                        10:29:25   Log-Likelihood:                         -8333.5
# No. Observations:                 545   AIC:                                  1.669e+04
# Df Residuals:                     534   BIC:                                  1.674e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
price_to_predict = pd.DataFrame({'area': [5600], 'bedrooms': [4], 'bathrooms': [2],
                                 'stories': [2], 'mainroad': ['no'], 'guestroom': ['no'],
                                 'basement': ['yes'], 'hotwaterheating': ['yes'],
                                 'airconditioning': ['no'], 'parking': 2, 'prefarea': ['yes'],
                                 'furnishingstatus': ['semi-furnished']})
price_to_predict
# Out:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  5600         4          2        2       no        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0             yes              no        2      yes   semi-furnished

# %%
price_to_predict['mainroad'] = pd.Categorical(price_to_predict['mainroad'], categories=['no', 'yes'])
price_to_predict['guestroom'] = pd.Categorical(price_to_predict['guestroom'], categories=['no', 'yes'])
price_to_predict['basement'] = pd.Categorical(price_to_predict['basement'], categories=['no', 'yes'])
price_to_predict['hotwaterheating'] = pd.Categorical(price_to_predict['hotwaterheating'], categories=['no', 'yes'])
price_to_predict['airconditioning'] = pd.Categorical(price_to_predict['airconditioning'], categories=['no', 'yes'])
price_to_predict['prefarea'] = pd.Categorical(price_to_predict['prefarea'], categories=['no', 'yes'])
price_to_predict['furnishingstatus'] = pd.Categorical(price_to_predict['furnishingstatus'], categories=['furnished', 'semi-furnished', 'unfurnished'])

# %%
price_to_predict = pd.get_dummies(price_to_predict, drop_first=True,
                                  columns=['mainroad', 'guestroom',
                                           'basement', 'hotwaterheating',
                                           'airconditioning','prefarea',
                                           'furnishingstatus'], dtype=int)
price_to_predict.head()
# Out:
#    area  bedrooms  bathrooms  stories  parking  mainroad_yes  guestroom_yes  \
# 0  5600         4          2        2        2             0              0
#
#    basement_yes  hotwaterheating_yes  airconditioning_yes  prefarea_yes  \
# 0             1                    1                    0             1
#
#    furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 0                                1                             0

# %%
price_to_predict = price_to_predict.drop(['bedrooms', 'furnishingstatus_semi-furnished'], axis=1)
price_to_predict
# Out:
#    area  bathrooms  stories  parking  mainroad_yes  guestroom_yes  \
# 0  5600          2        2        2             0              0
#
#    basement_yes  hotwaterheating_yes  airconditioning_yes  prefarea_yes  \
# 0             1                    1                    0             1
#
#    furnishingstatus_unfurnished
# 0                             0

# %%
predict_value = model.predict(price_to_predict)
print(predict_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 predict_value = model.predict(price_to_predict)
#       2 print(predict_value)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\regression\linear_model.py:409, in RegressionModel.predict(self, params, exog)
#     406 if exog is None:
#     407     exog = self.exog
# --> 409 return np.dot(exog, params)
#
# ValueError: shapes (545,11) and (1,11) not aligned: 11 (dim 1) != 1 (dim 0)
