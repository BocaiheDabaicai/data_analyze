# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 绘制散点图

# %%
# 导入本节示例数据，注意此文件并非本地数据文件，而是从Seaborn库里导入的
# Seaborn库里的所有数据可以在这里查看：https://github.com/mwaskom/seaborn-data
# 如果遇到导入问题，可以从以上GitHub仓库下载到本地，然后读取文件
# 或者是参考https://blog.csdn.net/weixin_51755670/article/details/127979895
df1 = sns.load_dataset("tips")
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 传入DataFrame作为数据，以total_bill为横轴数据，tip为纵轴数据，绘制散点图
sns.scatterplot(data=df1,x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# 传入Series作为数据，以df1的total_bill为横轴数据，df1的tip为纵轴数据，绘制散点图
sns.scatterplot(x=df1["total_bill"], y=df1["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## 绘制折线图

# %%
# 导入示例数据
df2 = sns.load_dataset("flights").query("month == 'Jan'")
df2
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 12   1950   Jan         115
# 24   1951   Jan         145
# 36   1952   Jan         171
# 48   1953   Jan         196
# 60   1954   Jan         204
# 72   1955   Jan         242
# 84   1956   Jan         284
# 96   1957   Jan         315
# 108  1958   Jan         340
# 120  1959   Jan         360
# 132  1960   Jan         417

# %%
# 以year为横轴数据，passengers为纵轴数据，绘制折线图
sns.lineplot(data=df2,x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ## 绘制条形图

# %%
# 导入示例数据
# df3 = sns.load_dataset("penguins")
df3 = pd.read_csv("../datas/penguins.csv")
df3
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
# 以species为横轴数据，body_mass_g为纵轴数据，聚合操作为求平均值，绘制条形图
sns.barplot(data=df3,x="species", y="body_mass_g",estimator=np.mean)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# 以species为横轴数据，body_mass_g为纵轴数据，聚合操作为求最大值，绘制条形图
sns.barplot(data=df3,x="species", y="body_mass_g",estimator=np.max)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ## 绘制计数图

# %%
# 以df3的species为横轴数据，绘制计数图
sns.countplot(data=df3,x="species")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# ## 绘制饼图

# %%
# 设置示例数据
df4 = pd.DataFrame({'fruit': ['apple', 'orange', 'banana', 'pear'],
                     'vote': [32, 22, 19, 7]})
df4
# Out:
#     fruit  vote
# 0   apple    32
# 1  orange    22
# 2  banana    19
# 3    pear     7

# %%
# 对df4的vote数据绘制饼图
plt.pie(df4['vote'])
# Out:
# ([<matplotlib.patches.Wedge at 0x28e276a8590>,
#   <matplotlib.patches.Wedge at 0x28e2848f110>,
#   <matplotlib.patches.Wedge at 0x28e2848f390>,
#   <matplotlib.patches.Wedge at 0x28e2848f610>],
#  [Text(0.33991865722907993, 1.0461621798113232, ''),
#   Text(-1.0696068653456368, -0.2567900963929123, ''),
#   Text(0.29858513083388877, -1.0587005807332448, ''),
#   Text(1.0587007788763734, -0.29858442827207293, '')])

# %%
# 对df4的vote数据绘制饼图，标签对应为df4的fruit数据
plt.pie(df4['vote'],labels=df4['fruit'])
# Out:
# ([<matplotlib.patches.Wedge at 0x28e285620d0>,
#   <matplotlib.patches.Wedge at 0x28e28562350>,
#   <matplotlib.patches.Wedge at 0x28e285625d0>,
#   <matplotlib.patches.Wedge at 0x28e28562850>],
#  [Text(0.33991865722907993, 1.0461621798113232, 'apple'),
#   Text(-1.0696068653456368, -0.2567900963929123, 'orange'),
#   Text(0.29858513083388877, -1.0587005807332448, 'banana'),
#   Text(1.0587007788763734, -0.29858442827207293, 'pear')])

# %%
# 对df4的vote数据绘制饼图，标签对应为df4的fruit数据，并在图表上展示比例数字，保留1位小数
plt.pie(df4['vote'],labels=df4['fruit'],autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x28e2859a0d0>,
#   <matplotlib.patches.Wedge at 0x28e2859a490>,
#   <matplotlib.patches.Wedge at 0x28e2859a850>,
#   <matplotlib.patches.Wedge at 0x28e2859ac10>],
#  [Text(0.33991865722907993, 1.0461621798113232, 'apple'),
#   Text(-1.0696068653456368, -0.2567900963929123, 'orange'),
#   Text(0.29858513083388877, -1.0587005807332448, 'banana'),
#   Text(1.0587007788763734, -0.29858442827207293, 'pear')],
#  [Text(0.18541017667040724, 0.5706339162607217, '40.0%'),
#   Text(-0.5834219265521654, -0.14006732530522487, '27.5%'),
#   Text(0.16286461681848477, -0.5774730440363153, '23.8%'),
#   Text(0.5774731521143853, -0.16286423360294885, '8.8%')])

# %% [markdown]
# ## 更改图表颜色

# %%
# 更改以下方法调用，把点的颜色改成红色
sns.scatterplot(df1, x="total_bill", y="tip", color='red')
plt.show()

# %%
# 更改以下方法调用，把线的颜色改成绿色
sns.lineplot(data=df2, x="year", y="passengers", color='green')
plt.show()

# %%
# 更改以下方法调用，把条柱的颜色改成#c287c7这个十六进制所对应的颜色
sns.histplot(data=df3, x="body_mass_g", color='#c287c7')
plt.show()

# %% [markdown]
# ## 更改图表色盘

# %%
# 更新下方代码，把条形图的色盘更改为“pastel”（注意一旦set_palette被调用后，将对之后所有绘制的图表生效）
sns.barplot(data=df3, x="species", y="body_mass_g")
sns.set_palette("pastel")
plt.show()

# %%
# 更新下方代码，把条形图的色盘更改为“crest”（注意一旦set_palette被调用后，将对之后所有绘制的图表生效）
sns.set_palette("crest")
sns.barplot(data=df3, x="species", y="body_mass_g")
plt.show()

# %%
sns.set_palette("muted")
sns.barplot(data=df3, x="species", y="body_mass_g")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>
