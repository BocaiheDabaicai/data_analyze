# %% [markdown]
# # 项目：可视化帕默群岛企鹅数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析报告的目的是对帕默群岛上企鹅样本的相关变量进行可视化，从而探索和分析种类、性别、所在岛屿等因素，与企鹅的身体属性，包括体重、嘴峰长度和深度、鳍的长度，之间的关系。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据`Penguins.csv`包括334个收集自南极洲帕尔默群岛的3个岛屿上的企鹅样本，以及企鹅相关属性数据，包括种类名、所在岛、嘴峰长度、嘴峰深度、鳍长度、体重、性别。
#
# `Penguins.csv`每列的含义如下：
# - species：企鹅的种类
# - island：企鹅所在岛
# - culmen_length_mm：企鹅嘴峰的长度（单位为毫米）
# - culmen_depth_mm：企鹅嘴峰的深度（单位为毫米）
# - flipper_length_mm：企鹅鳍的长度（单位为毫米）
# - body_mass_g：企鹅体重（单位为克）
# - sex：企鹅性别

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
penguins_list = pd.read_csv('../datas/penguins.csv')
penguins_list
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
penguins_list[penguins_list['culmen_length_mm'].isnull()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
penguins_list.drop(3,inplace=True)
penguins_list.drop(339,inplace=True)

# %%
penguins_list[penguins_list['culmen_depth_mm'].isnull()]
# Out:
# Empty DataFrame
# Columns: [species, island, culmen_length_mm, culmen_depth_mm, flipper_length_mm, body_mass_g, sex]
# Index: []

# %%
penguins_list[penguins_list['flipper_length_mm'].isnull()]
# Out:
# Empty DataFrame
# Columns: [species, island, culmen_length_mm, culmen_depth_mm, flipper_length_mm, body_mass_g, sex]
# Index: []

# %%
penguins_list[penguins_list['body_mass_g'].isnull()]
# Out:
# Empty DataFrame
# Columns: [species, island, culmen_length_mm, culmen_depth_mm, flipper_length_mm, body_mass_g, sex]
# Index: []

# %%
penguins_list[penguins_list['sex'].isnull()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 8    Adelie  Torgersen              34.1             18.1              193.0
# 9    Adelie  Torgersen              42.0             20.2              190.0
# 10   Adelie  Torgersen              37.8             17.1              186.0
# 11   Adelie  Torgersen              37.8             17.3              180.0
# 47   Adelie      Dream              37.5             18.9              179.0
# 246  Gentoo     Biscoe              44.5             14.3              216.0
# 286  Gentoo     Biscoe              46.2             14.4              214.0
# 324  Gentoo     Biscoe              47.3             13.8              216.0
#
#      body_mass_g  sex
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# 11        3700.0  NaN
# 47        2975.0  NaN
# 246       4100.0  NaN
# 286       4650.0  NaN
# 324       4725.0  NaN

# %%
penguins_list.dropna(subset=['sex'],inplace=True)

# %%
penguins_list[penguins_list['sex'].isnull()]
# Out:
# Empty DataFrame
# Columns: [species, island, culmen_length_mm, culmen_depth_mm, flipper_length_mm, body_mass_g, sex]
# Index: []

# %%
penguins_list
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
penguins_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
penguins_list["species"] = penguins_list["species"].astype("category")
penguins_list["island"] = penguins_list["island"].astype("category")
penguins_list["sex"] = penguins_list["sex"].astype("category")

# %%
penguins_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    category
#  1   island             334 non-null    category
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    category
# dtypes: category(3), float64(4)
# memory usage: 14.4 KB

# %%
penguins_list.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        334.000000       334.000000         334.000000   334.000000
# mean          43.994311        17.160479         201.014970  4209.056886
# std            5.460521         1.967909          14.022175   804.836129
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.500000        15.600000         190.000000  3550.000000
# 50%           44.500000        17.300000         197.000000  4050.000000
# 75%           48.575000        18.700000         213.000000  4793.750000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
penguins_list["sex"].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64

# %%
penguins_list["sex"] = penguins_list["sex"].replace(".",np.nan)
# Out:
# C:\Users\NfryCreator\AppData\Local\Temp\ipykernel_176\1465467258.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   penguins_list["sex"] = penguins_list["sex"].replace(".",np.nan)

# %%
penguins_list["sex"].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %%
sns.set_palette("muted")

# %%
penguins_list
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
species_list = penguins_list["species"].value_counts()
species_list
# Out:
# species
# Adelie       146
# Gentoo       120
# Chinstrap     68
# Name: count, dtype: int64

# %%
plt.pie(species_list,labels=species_list.index,autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c0f2362210>,
# ...
#  [Text(0.21586760235177765, 1.0786107630906039, 'Adelie'),
#   Text(-0.8169976262825709, -0.7365560933483917, 'Gentoo'),
#   Text(0.8825645182221321, -0.6565667301770142, 'Chinstrap')],
#  [Text(0.11774596491915143, 0.5883331435039657, '44%'),
#   Text(-0.4456350688814023, -0.4017578690991227, '36%'),
#   Text(0.48139882812116286, -0.3581273073692804, '20%')])

# %%
islands_list = penguins_list["island"].value_counts()
islands_list
# Out:
# island
# Biscoe       164
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
plt.pie(islands_list,labels=islands_list.index,autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c0f23c20d0>,
# ...
#  [Text(0.031035535762868726, 1.0995620926168344, 'Biscoe'),
#   Text(-0.498467420799276, -0.9805764786092503, 'Dream'),
#   Text(0.9942499759189304, -0.4706027893937801, 'Torgersen')],
#  [Text(0.016928474052473847, 0.5997611414273641, '49%'),
#   Text(-0.2718913204359687, -0.5348598974232274, '37%'),
#   Text(0.5423181686830528, -0.25669243057842545, '14%')])

# %%
sex_list = penguins_list["sex"].value_counts()
sex_list
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %%
plt.pie(sex_list,labels = sex_list.index,autopct="%1.0f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1c0f23edf90>,
# ...
#  [Text(-0.01556599676421093, 1.0998898580061263, 'MALE'),
#   Text(0.015565699568373776, -1.0998898622120976, 'FEMALE')],
#  [Text(-0.008490543689569597, 0.5999399225487961, '50%'),
#   Text(0.008490381582749331, -0.5999399248429623, '50%')])

# %%
sns.countplot(penguins_list,x="island",hue="species")
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
sns.countplot(penguins_list,x="island",hue="sex")
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
sns.pairplot(penguins_list)

# %%
sns.pairplot(penguins_list,hue="species",kind="reg",plot_kws={"scatter_kws":{"alpha":0.5}})

# %%
sns.pairplot(penguins_list,hue="sex",kind="reg",plot_kws={"scatter_kws":{"alpha":0.5}})
